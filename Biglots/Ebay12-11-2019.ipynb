# %%
import requests



from fake_useragent import UserAgent
from bs4 import BeautifulSoup
# Out:
#   File "<ipython-input-76-f9e5518a2970>", line 3
#     return requests.get(url).json()
#                                    ^
# SyntaxError: 'return' outside function

# %%
ua = UserAgent()
header = {'User-Agent': str(ua.random)}
result = requests.get('https://www.ebay.com/sch/i.html?_from=R40&_trksid=m570.l1313&_nkw=badminton+net+sportcraft', headers=header).content

# %%
soup = BeautifulSoup(result, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]><html class="ie9 srp-ds6" lang="en"><![endif]--><!--[if gt IE 9]><!--><html class="srp-ds6" lang="en"><!--<![endif]--><head><meta content="IE=edge" http-equiv="X-UA-Compatible"/><script>"use strict";if(window.PerformanceObserver&&performance&&performance.mark&&performance.getEntriesByName){window.SRP=window.SRP||{};var paintObserver=new window.PerformanceObserver(function(e){var r=e.getEntries();r.sort(function(e,r){return e.startTime-r.startTime});var n=r[1].startTime;window.SRP.TTI_TIMER={lastInteractiveWindow:n};var t=new window.PerformanceObserver(function(e){for(var r=e.getEntries(),i=0,a=r.length;i<a;i++)r[i].startTime-n>=5e3&&(window.SRP.TTI_TIMER.timeToInteract=n,t.disconnect()),n=r[i].startTime+r[i].duration,window.SRP.TTI_TIMER.lastInteractiveWindow=n});t.observe({entryTypes:["longtask"]}),paintObserver.disconnect()});paintObserver.observe({entryTypes:["paint"]})};</script><meta content="34E98E6F27109BE1A9DCF19658EEEE33" name="msvalidate.01"><meta content="6e11485a66d91eff" name="yandex-verification"/><link href="https://ir.ebaystatic.com" rel="preconnect"/><link href="https://i.ebayimg.com" rel="preconnect"/><meta content="noindex" name="robots"/><meta content="acf32e2a69cbc2b0" name="y_key"/><title>badminton net sportcraft | eBay</title><meta content="Find great deals on eBay for badminton net sportcraft. Shop with confidence." name="description"/><meta content="8kHr3jd3Z43q1ovwo0KVgo_NZKIEMjthBxti8m8fYTg" name="google-site-verification"/><meta content="unsafe-url" name="referrer"/><meta content="102628213125203" property="fb:app_id"/><!-- NGMARS SIGNATURE --><link href="//i.ebayimg.com" rel="dns-prefetch"/><link href="//thumbs.ebaystatic.com" rel="dns-prefetch"/><link href="//thumbs1.ebaystatic.com" rel="dns-prefetch"/><link href="//thumbs2.ebaystatic.com" rel="dns-prefetch"/><link href="//thumbs3.ebaystatic.com" rel="dns-prefetch"/><link href="//thumbs4.ebaystatic.com" rel="dns-prefetch"/><link href="//vi.vipr.ebaydesc.com" rel="dns-prefetch"/><link href="//q.ebaystatic.com" rel="dns-prefetch"/><link href="//pics.ebaystatic.com" rel="dns-prefetch"/><link href="//ir.ebaystatic.com" rel="dns-prefetch"/><link href="//tags.bluekai.com" rel="dns-prefetch"/><link href="//srx.main.ebayrtm.com" rel="dns-prefetch"/><link href="//rover.ebay.com" rel="dns-prefetch"/><link href="//reco.ebay.com" rel="dns-prefetch"/><link href="//ads.ebay.com" rel="dns-prefetch"/><link href="//svcs.ebay.com" rel="dns-prefetch"/><link href="https://ir.ebaystatic.com" rel="dns-prefetch"/><link href="https://thumbs.ebaystatic.com" rel="dns-prefetch"/><meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/><link href="//ir.ebaystatic.com" rel="dns-prefetch"/><link href="//secureir.ebaystatic.com" rel="dns-prefetch"/><link href="//i.ebayimg.com" rel="dns-prefetch"/><link href="//rover.ebay.com" rel="dns-prefetch"/><script>$ssgST=new Date().getTime();</script><link href="https://ir.ebaystatic.com/rs/c/inception-nfyRivkR.css" rel="stylesheet"/>
# <link href="https://ir.ebaystatic.com/rs/c/search-page-large-mRui_pGf.css" rel="stylesheet"/><link href="https://ir.ebaystatic.com/rs/v/lkh51jifby2hfkfn0zmr5shzwyd.css?proc=DU:N" rel="stylesheet" type="text/css"/><noscript data-widget="/sfe-scandal-client$2.1.0/tags/manager/widget" id="w0"></noscript></meta></head><body class="s-page no-touch skin-large"><noscript class="x-page-config" data-widget="/srpnweb$1.0.0/src/fe-components/x-page-config/index" id="w1"></noscript><div class="x-header"><style>.gh-hide-if-nocss{display:none;}.gh-ar-hdn{color:#fff}</style> <div class="gh-acc-exp-div gh-hide-if-nocss"><a class="gh-acc-a" href="#mainContent" id="gh-hdn-stm">Skip to main content</a></div><!--[if lt IE 9]><div id="gh" role="banner" class="gh-IE8 gh-flex gh-pre-js gh-w "><![endif]--><header class="gh-flex gh-pre-js gh-w" id="gh" role="banner"><table class="gh-tbl" role="presentation"><tbody><tr><td class="gh-td"><!--[if lt IE 9]><a href="https://www.ebay.com/" _sp="m570.l2586" id="gh-la">eBay Logo<img role="presentation" width=117 height=120 style='clip:rect(47px, 118px, 95px, 0px); position:absolute; top:-47px;left:0' alt="eBay Logo" src="https://ir.ebaystatic.com/rs/v/apstidvcvu5pxlbxkphrrdo5iqv.png" id="gh-logo"></a><![endif]--><a _sp="m570.l2586" href="https://www.ebay.com/" id="gh-la">eBay Logo<img alt="eBay Logo" height="200" id="gh-logo" role="presentation" src="https://ir.ebaystatic.com/rs/v/fxxj3ttftm5ltcqnto1o4baovyl.png" style="clip:rect(47px, 118px, 95px, 0px); position:absolute; top:-47px;left:0" width="250"/></a></td><td class="gh-td"><div class="gh-hide-if-nocss" id="gh-shop"><button aria-controls="gh-sbc-o" aria-expanded="false" class="gh-control" id="gh-shop-a">Shop by category<i class="gh-sprRetina" id="gh-shop-ei"></i></button><div id="gh-sbc-o"><h2 class="gh-ar-hdn">Shop by category</h2></div></div></td><td class="gh-td-s"><form action="/sch/i.html" id="gh-f" method="get"><input name="_from" type="hidden" value="R40"/><input name="_trksid" type="hidden" value="m570.l1313"/><table class="gh-tbl2" role="presentation"><tbody><tr><td class="gh-td-s"><div id="gh-ac-box"><div id="gh-ac-box2"><label class="gh-ar-hdn" for="gh-ac">Enter your search keyword</label><input autocapitalize="off" autocomplete="off" autocorrect="off" class="gh-tb ui-autocomplete-input" id="gh-ac" label="Search for anything" maxlength="300" name="_nkw" placeholder="Search for anything" size="50" spellcheck="false" type="text" value="badminton net sportcraft"/><script> if(document.getElementById('gh-ac').value.length !== 0) { document.getElementById('gh-ac-box').classList.add('gh-ac-box-focus'); document.getElementById('gh').classList.add('gh-sch-focus'); } </script></div></div></td><td class="gh-td" id="gh-cat-td"><div id="gh-cat-box"><select aria-label="Select a category for search" class="gh-sb gh-sprRetina" id="gh-cat" name="_sacat" size="1"><option value="0">All Categories</option><optgroup label="----------------------------------------"></optgroup><option value="20081">Antiques</option><option value="550"> Art</option><option value="2984"> Baby</option><option value="267"> Books</option><option value="12576"> Business &amp; Industrial</option><option value="625"> Cameras &amp; Photo</option><option value="15032"> Cell Phones &amp; Accessories</option><option value="11450"> Clothing, Shoes &amp; Accessories</option><option value="11116"> Coins &amp; Paper Money</option><option value="1"> Collectibles</option><option value="58058"> Computers/Tablets &amp; Networking</option><option value="293"> Consumer Electronics</option><option value="14339"> Crafts</option><option value="237"> Dolls &amp; Bears</option><option value="11232"> DVDs &amp; Movies</option><option value="6000"> eBay Motors</option><option value="45100"> Entertainment Memorabilia</option><option value="99"> Everything Else</option><option value="172008"> Gift Cards &amp; Coupons</option><option value="26395"> Health &amp; Beauty</option><option value="11700"> Home &amp; Gar ...
# "use strict";var SITE_SPEED=SITE_SPEED||{};SITE_SPEED.ATF_TIMER={measure:function(t){t.setAttribute("data-atftimer",Date.now())}};</script></div><div aria-hidden="true" class="s-prefetch-image" style="display:none;"><img importance="high" src="https://i.ebayimg.com/thumbs/images/g/W68AAOSw7cldBun-/s-l225.jpg"/><img importance="high" src="https://i.ebayimg.com/thumbs/images/m/mVGUvN1c4SVzz10nJ4L4wyQ/s-l225.jpg"/></div><script>!function(){var e=document.querySelector(".s-progressive-spinner");e&&e.parentNode.removeChild(e)}();</script><script>
# var headerDiv = document.querySelector('.x-header');
# document.body.className += ' srp--list-view no-touch skin-large';
# if (headerDiv) headerDiv.className += '';
# </script><noscript data-widget="/srpnweb$1.0.0/src/fe-components/x-update-global-header/widget" id="w2"></noscript><script>
# window.SRP = window.SRP || {};
# window.SRP.ATF_IMGS = 5;
# </script><script>var GLOBAL_CONTENT = {"FILTER_APPLIED":"Filter Applied","TOMORROW":"Tomorrow","TODAY":"Today","WAITING_FOR_RESPONSE":"Loading...","SERVICE_FAILED_MSG":"There seems to be a problem serving the request at this time","locale":"en-US"}</script><style type="text/css">
# span.s-qd9gx2 {
#     display: inline;
# }
# span.s-jm3aicp {
#     display: none;
# }
# </style><div class="srp-main srp-main--isLarge"><div class="s-answer-region s-answer-region-above-river"></div><div class="srp-include-description" data-widget="/srpnweb$1.0.0/src/fe-components/s-include-description/widget" id="w3"><label data-w-onclick="updateGlobalHeader|w3" for="w3_incl_desc"><input id="w3_incl_desc" type="checkbox"/>Include description</label></div><section class="srp-high-section"><div class="s-answer-region s-answer-region-high-section"></div></section><div class="srp-rail__left"><div class="s-answer-region s-answer-region-left-rail"></div><ul class="x-refine__body x-refine__body--flush-left x-refine__body--has-toggle" data-widget="/srpnweb$1.0.0/src/fe-components/x-refine-v2/components/x-refine-inner/refine-widget" id="w4"><li><ul class="x-refine__left__nav"><li class="x-refine__main__list"><div><h3 class="x-refine__item">Categories</h3></div><div class="x-refine__group" id="x-refine__group__0"><ul class="srp-refine__category__list"><li class="srp-refine__category__item" data-expansion="OPEN_PRIMARY" data-scope="PRIMARY" data-state="selected"><span tabindex="0"><span class="clipped">Selected category</span>All</span><ul class="srp-refine__category__list"><li class="srp-refine__category__item" data-expansion="OPEN_PRIMARY" data-scope="PRIMARY"><a _sp="p2351460.m4118.l9012" data-track='{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"moduledtl":"mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3A_sacat%7Cli%3A8173%7Cluid%3A1%7C","pageci":"612010d9-052d-11ea-a207-74dbd1809a38","parentrq":"5ee82e7916e0aad2e0f9ecd6fffa9fc0"}}' href="https://www.ebay.com/sch/888/i.html?_from=R40&amp;_nkw=badminton+net+sportcraft"><span>Sporting Goods</span></a><ul class="srp-refine__category__list"><li class="srp-refine__category__item" data-expansion="OPEN_PRIMARY" data-scope="PRIMARY"><a _sp="p2351460.m4118.l9012" data-track='{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"moduledtl":"mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3A_sacat%7Cli%3A8173%7Cluid%3A2%7C","pageci":"612010d9-052d-11ea-a207-74dbd1809a38","parentrq":"5ee82e7916e0aad2e0f9ecd6fffa9fc0"}}' href="https://www.ebay.com/sch/159131/i.html?_from=R40&amp;_nkw=badminton+net+sportcraft"><span>Volleyball Nets</span></a></li><li class="srp-refine__category__item" data-expansion="OPEN_PRIMARY" data-scope="PRIMARY"><a _sp="p2351460.m4118.l9012" data-track='{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"moduledtl":"mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3A_sacat%7Cli%3A8173%7Cluid%3A3%7C","pageci":"612010d9-052d-11ea-a207-74dbd1809a38","parentrq":"5ee82e7916e0aad2e0f9ecd6fffa9fc0"}}' href="https://www.ebay.com/sch/106460/i.html?_from=R40&amp;_nkw=badminton+net+sportcraft"><span>Badminton Equipment</span></a></li></ul></li></ul></li></ul></div></li><li class="x-refine__main__list"><div aria-controls="x-refine__group__1" aria-expanded="true" class="x-refine__item--toggle" role="button" tabindex="0"><h3 class="x-refine__item">Condition</h3><div class="x-refine-toggle" data-widget="/srpnweb$1.0.0/src/fe-components/x-refine-v2/components/x-toggle/widget" id="w4-w0"><svg focusable="false"><use xlink:href="#svg-icon-chevron-down"></use></svg></div></div><div class="x-refine__group" id="x-refine__group__1"><ul class="x-refine__main__value" style="clear:both"><li class="x-refine__main__list--value"><div class="x-refine__multi-select"><a _sp="p2351460.m4118.c1" class="cbx x-refine__multi-select-link" data-track='{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"moduledtl":"mi%3A4118%7Ciid%3A1%7C ...
# window.SRP = window.SRP || {};
# window.SRP.LENSPATH = 'www.ebay.com/pi/layer';
# </script><div class="srp-main-below-river"><div class="s-answer-region s-answer-region-below-river"><div class="scandal-placement" data-widget="/sfe-scandal-client$2.1.0/tags/placeholder/widget" id="scandal100659" title="ADVERTISEMENT"></div><div class="scandal-placement" data-widget="/sfe-scandal-client$2.1.0/tags/placeholder/widget" id="scandal100589" title="ADVERTISEMENT"></div></div></div><div class="srp-rtm-placeholder" data-position="below_pagination" data-widget="/srpnweb$1.0.0/src/fe-components/s-rtm-placeholder/index" id="w16"></div><div class="srp-rtm-manager hide" data-widget="/srpnweb$1.0.0/src/fe-components/s-rtm-manager/index" id="w17"></div></div><div class="srp-rail__right"><div class="s-answer-region s-answer-region-right-rail"><div class="scandal-placement" data-widget="/sfe-scandal-client$2.1.0/tags/placeholder/widget" id="scandal100584" title="ADVERTISEMENT"></div></div></div><div class="s-feedback"><div class="s-feedback-header">Feedback</div><a href="http://connect.ebay.com/srv/survey/a/search.srp.node?ctx=url%3D%2Fsch%2Fi.html%3F_from%3DR40%26_trksid%3Dm570.l1313%26_nkw%3Dbadminton%2Bnet%2Bsportcraft" target="_blank"><div class="s-feedback-survey"><span class="clipped">Leave feedback about your eBay search experience - opens in new window or tab</span></div></a></div></div><div class="x-footer"><div class="s-answer-region"><noscript data-widget="/sfe-scandal-client$2.1.0/tags/placeholder/widget" id="w18"></noscript><noscript data-widget="/sfe-scandal-client$2.1.0/tags/placeholder/widget" id="w19"></noscript><noscript data-widget="/sfe-scandal-client$2.1.0/tags/placeholder/widget" id="w20"></noscript></div>
# <div id="widget-platform">
# <script type="application/javascript">window.widget_platform = {"renderType":1,"renderDelay":500,"triggerFallBack":true,"status":4,"queryParam":null,"widgets":[{"html":"","css":null,"js":null,"jsInline":null,"init":""}],"showdiag":[]};</script>
# <div id="gh_user" style="display:none;"></div>
# </div>
# <!--[if lt IE 9]><div id="glbfooter" role="contentinfo" class="gh-w gh-flex"><![endif]--><footer class="gh-w gh-flex" id="glbfooter" role="contentinfo"><div><div id="rtm_html_1650"></div><div id="rtm_html_1651"></div></div><h2 class="gh-ar-hdn">Additional site navigation</h2><div id="gf-t-box"><table class="gf-t" role="presentation"><tr><td colspan="2"><ul class="gh-hide-if-nocss" id="gf-l"><li class="gf-li"><a _exsp="m571.l2602" class="thrd gf-bar-a" href="https://www.ebayinc.com">About eBay</a></li><li class="gf-li"><a _exsp="m571.l2935" class="thrd gf-bar-a" href="http://announcements.ebay.com">Announcements</a></li><li class="gf-li"><a _exsp="m571.l1540" class="thrd gf-bar-a" href="http://community.ebay.com">Community</a></li><li class="gf-li"><a _exsp="m571.l2616" class="thrd gf-bar-a" href="https://pages.ebay.com/securitycenter/index.html">Security Center</a></li><li class="gf-li"><a _sp="m571.l1619" class="thrd gf-bar-a" data-sp="m571.l1619" href="https://resolutioncenter.ebay.com/">Resolution Center</a></li><li class="gf-li"><a _exsp="m571.l1613" class="thrd gf-bar-a" href="http://pages.ebay.com/sellerinformation/index.html">Seller Information Center</a></li><li class="gf-li"><a _exsp="m571.l2604" class="thrd gf-bar-a" href="https://pages.ebay.com/help/policies/overview.html">Policies</a></li><li class="gf-li"><a _exsp="m571.l3947" class="thrd gf-bar-a" href="https://www.ebaypartnernetwork.com/files/hub/en-US/index.html">Affiliates</a></li><li class="gf-li"><a _sp="m571.l1545" class="thrd gf-bar-a" data-sp="m571.l1545" href="https://ocsnext.ebay.com/ocs/home">Help &amp; Contact</a></li><li class="gf-li"><a _exsp="m571.l2909" class="thrd gf-bar-a" href="https://pages.ebay.com/sitemap.html">Site Map</a></li></ul></td></tr><tr valign="top"><td class="gf-legal">Copyright © 1995-2019 eBay Inc. All Rights Reserved. <a href="https://www.ebayinc.com/accessibility/">Accessibility</a>, <a href="https://pages.ebay.com/help/policies/user-agreement.html">User Agreement</a>, <a href="https://pages.ebay.com/help/policies/privacy-policy.html">Privacy</a>, <a href="https://pages.ebay.com/help/account/cookies-web-beacons.html">Cookies</a> and <a href="https://www.ebay.com/adchoice" id="gf-AdChoice">AdChoice</a></td><td align="center" nowrap=""><a _exsp="m571.l3943" href="https://trustsealinfo.websecurity.norton.com/splash?form_file=fdf/splash.fdf&amp;dn=www.ebay.com&amp;lang=en" onclick="this.href='https://trustsealinfo.websecurity.norton.com/splash?form_file=fdf/splash.fdf&amp;dn=#D#&amp;lang=en'.replace(/#D#/,location.host);return true" rel="noreferrer" title="Verify site's SSL certificate"><i id="gf-norton">Norton Secured - powered by Verisign</i></a></td></tr></table></div><!--[if lt IE 9]></div><![endif]--></footer><div class="s-footer-notes"><div class="s-footer-notes--entry"><a href="https://pages.ebay.com/buy/popup/pricing.html">*Learn about pricing</a></div><div class="s-footer-notes--entry">This page was last updated: 12-Nov 02:18. Number of bids and bid amounts may be slightly out of date. See each listing for international shipping options and costs.</div></div></div><div class="hide" data-widget="/srpnweb$1.0.0/src/fe-components/x-tracking/index" id="w21"></div><div class="srp-mask" data-widget="/srpnweb$1.0.0/src/fe-components/s-mask/index" id="w22"></div><div class="s-modal-wrapper"><svg hidden=""><symbol id="ebayui-overlay-svg-icon-close" viewbox="0 0 32 32"><path d="M31.427 2.846l-2.387-2.387-13.084 13.082-13.082-13.082-2.386 2.387 13.082 13.082-13.082 13.084 2.386 2.386 13.082-13.082 13.084 13.082 2.386-2.386-13.084-13.084z"></path></symbol></svg><div aria-labelledby="ebayui-overlay__title" class="ebayui-overlay s-modal ebayui-overlay--popover dialog" data-w-body="0" data-widget="/sfe-ebayui-overlay$1.1.1/index" hidden="" id="s-modal" role="dialog"><div class="ebayui-overlay__container--popover dialog__window dialog__window--popover" role="document" style="width: auto; height: 100%;"><header aria-live="polite" class="e ...
# window.SFE && window.SFE.LazyLoading && window.SFE.LazyLoading.initialize(300);
# </script><script src="https://ir.ebaystatic.com/rs/c/inception-co76eqz-.js"></script>
# <script src="https://ir.ebaystatic.com/rs/c/search-page-large-u3EnSy2E.js"></script>
# <script>$_mod.ready();</script><script src="https://ir.ebaystatic.com/rs/v/o0rntwzyuy45plh0jrfkmehjkqv.js" type="text/javascript"></script><script src="https://ir.ebaystatic.com/rs/c/makeebayfasterscript-src-scripts-body-78a2168a.js" type="text/javascript"></script><script type="text/javascript"> (function(){ if(typeof(GH) !== 'undefined' && typeof(GH.add ) === 'function' ){ GH.add("GHModal__INIT_DATA", { ajaxURL: "/gh/shipto?modules=SHIP_TO_LOCATION", clickTriggerId: "gh-shipto-click", fetchMaxTimeOut: 6000, modalTitleId: "gh-shipto-label" }); } })(); (function(){ if(typeof(GH) !== 'undefined' && typeof(GH.add ) === 'function' ){ GH.add("GHShipTo__INIT_DATA", { clickTriggerId: "gh-shipto-click" }); } })(); if(typeof GH!="undefined"&&GH){GH.urls={ autocomplete_js:"https://ir.ebaystatic.com/rs/c/desktop_ac-10292019.js",fnet_js:"https://c.paypal.com/da/r/efb.js",ie8_js:"http://ir.ebaystatic.com/f/rbezfuzpu20wfd2kvejeb5adxyg.js",scandal_js:"https://ir.ebaystatic.com/cr/v/c1/ScandalJS-1.2.0-v4.min.js",widget_delivery_platform:"https://ir.ebaystatic.com/cr/v/c1/globalheader_widget_platform__v1-49d3462703.js" }; GH.GHSW={ raptor:0,sandbox:0,emp:0,ac1:0,ac2:0,ac3:0,ac4:0,ac5:0,ac6:0,hideMobile:"true",langSwitch:0,pool:0,ALERT_POPUPOFF:0,NEWALERT_POPUPOFF:0,newprofile:0,desktop_new_profile_service:"true",UNLOAD_Firefox:0,UNLOAD_Chrome:0,UNLOAD_IE:0,UNLOAD_Safari:0,ENABLE_HTTPS:"true",SEARCH_PROM:0,MINICART:0 };} if(typeof GH!="undefined" && GH){GH_config={"xhrBaseUrl":"https://www.ebay.com","siteId":"900","geoLang":"[]","suppressGeoUserUpdateInfo":"false","lng":"en-US","env":"production",sin:0,ct:0,pageId:2334524,geoul:'IN',langs:1,selectedCatId:'0',fn:"",id:""};GH.init();}</script><img alt="" border="0" height="0" src="https://rover.ebay.com/roversync/?site=0&amp;stg=1&amp;mpt=1573550304901" style="display:none" width="0"><script type="text/javascript">(function(scope) {var trackingInfo = {"X_EBAY_C_CORRELATION_SESSION":"si=5ee82e7e16e0aad2e0f36f29ffe8b1e3,c=1,sid=m570.l1313,operationId=2351460,trk-gflgs=QAE*"};scope.trkCorrelationSessionInfo={};scope.trkCorrelationSessionInfo.getTrackingInfo=function(){return trackingInfo;};scope.trkCorrelationSessionInfo.getTrackingCorrelationSessionInfo=function(){return trackingInfo.X_EBAY_C_CORRELATION_SESSION};})(window)</script><script type="text/javascript">if(typeof raptor !== "undefined" && raptor.require){var Uri=raptor.require("ebay/legacy/utils/Uri");$uri=function(href){return new Uri(href);};window.raptor.extend(window.raptor, require("ebay/legacy/adaptor-utils"));}</script><script id="taasHeaderRes" src="https://ir.ebaystatic.com/rs/v/10341xh50yz21mhhydueu4m5wad.js" type="text/javascript"></script><script id="taasContent" type="text/javascript">try {new window.TaaSTrackingCore({"psi":"A6C6jR2Y*","rover":{"imp":"/roverimp/0/0/9","clk":"/roverclk/0/0/9","uri":"https://rover.ebay.com"},"pid":"p2351460"});
# var RoverSyncDropped = true;
# var _plsubtInp={"eventFamily":"DFLT","samplingRate":100, "pageLoadTime": new Date().getTime(), "pageId":2351460, "app":"Testapp", "disableImp":true};var _plsUBTTQ=[];var TaaSIdMapTrackerObj = new TaaSIdMapTracker();TaaSIdMapTrackerObj.roverService("https://rover.ebay.com/idmap/0?footer");} catch (err) { console && console.log && console.log(err); }</script><script id="taasFooterRes" src="https://ir.ebaystatic.com/rs/v/it02syay0qyozhdaszhv1jl4yyd.js" type="text/javascript"></script> <script>if(window.$ssg) { $ssg({bRsTiming:false, iST:$ssgST, st1a:313, sUrl:"https://sofe.ebay.com/ws/web/SojPagePerf?cmdname=srpnweb_large&s_app_name=srpnweb&pagename=srpnweb&cxy=lvssrpnweb-3701564&s_host=lvssrpnweb-3701564&s_10s=UFES2-SIN-dweb-1%2C%20UFES1-SIN&st1=1573550304885", aChunktimes:[313,266,313]}); }</script><script>
# window.SRP = window.SRP || {};
# window.SRP.SERVICES_TIMER = {"combinedCassiniTime":150,"fisngTime":130,"mskuCassiniTime":20,"mainCassiniTime":130,"expSvcTime":246};
# </script><script>(function() {var t=window.$markoWidgetsState||(window.$markoWidgetsState={})
# var $={"w3":{"paramKey":"LH_TitleDesc"},"w4-w4-0":{"ariaInvalid":false,"item":{"_type":"PriceRangeEntrySelection","validations":[{"_type":"CurrencyValidation","message":{"title":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Please provide a valid price range"}]},"messageType":"ERROR"},"primitiveType":"DECIMAL_UNSIGNED","required":false,"contentType":"CUSTOM","lowerLimit":0}],"beginParamKey":"_udlo","endParamKey":"_udhi","beginLabel":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"INR","styles":["x-refine__price__label--begin"]}]},"middleLabel":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"- ","styles":["x-refine__price__label--middle"]},{"_type":"TextSpan","text":"INR","styles":["x-refine__price__label--middle"]}]},"beginPlaceHolder":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Minimum Value"}],"accessibilityText":"Minimum Value"},"endPlaceHolder":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Maximum Value"}],"accessibilityText":"Maximum Value"},"beginClear":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Clear Minimum Value"}]},"endClear":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Clear Maximum Value"}]},"minOnlyAccessoryLabel":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Over ${minValue}"}]},"maxOnlyAccessoryLabel":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Under ${maxValue}"}]},"minAndMaxAccessoryLabel":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"${minValue} - ${maxValue}"}]},"priceHint":{"_type":"IconDisplayType","icon":"SUBMIT_BUTTON","toolTipText":"Submit price range","action":{"_type":"Action","type":"NAV","trackingList":[{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"moduledtl":"mi%3A4118%7Ciid%3A1%7Cli%3A8316%7Cluid%3A9%7C%7C","pageci":"612010d9-052d-11ea-a207-74dbd1809a38","parentrq":"5ee82e7916e0aad2e0f9ecd6fffa9fc0"}},{"actionKind":"NAV","actionKinds":["NAV"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"sid":"p2351460.m4118.l8316.c0"}}]}}},"endTextSpans":[],"lowKey":"_udlo","highKey":"_udhi","lowValue":"","highValue":"","hasLow":false,"hasHigh":false,"minAccessibility":"Minimum Value","maxAccessibility":"Maximum Value","hintText":"Submit price range","_sp":"p2351460.m4118.l8316.c0","data_track":"{\"eventFamily\":\"LST\",\"eventAction\":\"ACTN\",\"actionKind\":\"NAVSRC\",\"actionKinds\":[\"NAVSRC\"],\"operationId\":\"2351460\",\"flushImmediately\":false,\"eventProperty\":{\"moduledtl\":\"mi%3A4118%7Ciid%3A1%7Cli%3A8316%7Cluid%3A9%7C%7C\",\"pageci\":\"612010d9-052d-11ea-a207-74dbd1809a38\",\"parentrq\":\"5ee82e7916e0aad2e0f9ecd6fffa9fc0\"}}","valid":false,"isRedesign":true,"buttonHref":"#svg-icon-arrow-right"},"scandal100588":{"adObj":{"_type":"SCANDAL_ADS_ANSWER","lazyLoad":false,"placementId":100588,"fallback":false,"resultCount":2,"json":"{\"targetingParameters\":{\"ap\":\"Scandal\",\"cat\":[],\"us\":\"13\",\"ot\":\"1\",\"kw\":\"badminton net sportcraft\",\"pr\":\"20\",\"xp\":\"20\",\"np\":\"20\",\"u\":\"082fa8da6c564b0a800e8f47a6b46663\",\"et\":[],\"ipp\":\"0\",\"iccr\":\"0\",\"gdprUser\":\"0\",\"plmtid\":\"100588\",\"acc\":\"ext\"},\"fallbackContent\":null,\"fallback\":false,\"pageId\":2334524,\"placementId\":100588,\"provider\":\"dfpNativeDisplay\",\"providerParameters\":{\"size\":{\"height\":229,\"width\":210},\"networkId\":\"79850875\",\"adUnitId\":\"ebay.gbh.search\",\"publishType\":2,\"scandalJS\":{\"scandalJsVersion\":\"2.1.4\",\"url\":\"//ir.ebaystatic.com/cr/v/c1/sc/ScandalJS-2.1.4.min.js\"},\"sizes\":[{\"height\":229,\"width\":210}],\"isGSSEnabled\":true,\"env\":\"production\",\"siteId\":900}}","flexible":true,"trackingInfo":{"moduleInstance":"mi:4658|iid:1","parentrq":"5ee82e7916e0aad2e0f9ecd6fffa9fc0","trackViews":true,"trackPerf":true},"locator":"scandal_ads_a ...
# $["w4-w4-0"].beginTextSpans=$["w4-w4-0"].item.beginLabel.textSpans
# $["w4-w4-0"].middleTextSpans=$["w4-w4-0"].item.middleLabel.textSpans
# t.w3=$.w3
# t["w4-w4-0"]=$["w4-w4-0"]
# t.scandal100588=$.scandal100588
# t.scandal100586=$.scandal100586
# t.scandal100587=$.scandal100587
# t["w11-follow"]=$["w11-follow"]
# t["srp-river-results-SEARCH_PAGINATION_MODEL_V2-w0"]=$["srp-river-results-SEARCH_PAGINATION_MODEL_V2-w0"]
# t["srp-river-results"]=$["srp-river-results"]
# t.scandal100659=$.scandal100659
# t.scandal100589=$.scandal100589
# t.w16=$.w16
# t.w17=$.w17
# t.scandal100584=$.scandal100584
# t.w18=$.w18
# t.w19=$.w19
# t.w20=$.w20
# t.w21=$.w21
# t.w22=$.w22
# t["s-modal"]=$["s-modal"]
# }());
# (function() {var t=window.$markoWidgetsConfig||(window.$markoWidgetsConfig={})
# var $={"w0":{"siteId":0,"pageCode":"1","isMobile":false},"w1":{"isDS6":true,"visibleClass":"s-qd9gx2","invisibleClass":"s-jm3aicp"},"w2":{"keyword":"badminton net sportcraft","categoryId":"0","refineCategories":[],"searchFormFields":[{"name":"LH_TitleDesc","value":0},{"name":"_odkw","value":"badminton net sportcraft"}]},"w3":{"isChecked":false},"w4-w0":{"isExpanded":true},"w4-w3":{"params":{"_fsrp":"1","_aspectname":"condition","_nkw":"badminton net sportcraft","_from":"R40","rt":"nc","pageci":"612010d9-052d-11ea-a207-74dbd1809a38","modules":"SEARCH_REFINEMENTS_MODEL_V2:fa"},"URL":"https://www.ebay.com/sch/i.html?_from=R40&_nkw=badminton+net+sportcraft&rt=nc&modules=SEARCH_REFINEMENTS_MODEL_V2%3Afa&_aspectname=condition&_fsrp=1&pageci=612010d9-052d-11ea-a207-74dbd1809a38"},"w4-w5":{"isExpanded":true},"w4-w10":{"params":{"_fsrp":"1","_aspectname":"format","_nkw":"badminton net sportcraft","_from":"R40","rt":"nc","pageci":"612010d9-052d-11ea-a207-74dbd1809a38","modules":"SEARCH_REFINEMENTS_MODEL_V2:fa"},"URL":"https://www.ebay.com/sch/i.html?_from=R40&_nkw=badminton+net+sportcraft&rt=nc&modules=SEARCH_REFINEMENTS_MODEL_V2%3Afa&_aspectname=format&_fsrp=1&pageci=612010d9-052d-11ea-a207-74dbd1809a38"},"w4-w11":{"isExpanded":true},"w4-w16":{"params":{"_fsrp":"1","_aspectname":"location","_nkw":"badminton net sportcraft","_from":"R40","rt":"nc","pageci":"612010d9-052d-11ea-a207-74dbd1809a38","modules":"SEARCH_REFINEMENTS_MODEL_V2:fa"},"URL":"https://www.ebay.com/sch/i.html?_from=R40&_nkw=badminton+net+sportcraft&rt=nc&modules=SEARCH_REFINEMENTS_MODEL_V2%3Afa&_aspectname=location&_fsrp=1&pageci=612010d9-052d-11ea-a207-74dbd1809a38"},"w4-w17":{"isExpanded":true},"w4-w19":{"params":{"_fsrp":"1","_aspectname":"delivery","_nkw":"badminton net sportcraft","_from":"R40","rt":"nc","pageci":"612010d9-052d-11ea-a207-74dbd1809a38","modules":"SEARCH_REFINEMENTS_MODEL_V2:fa"},"URL":"https://www.ebay.com/sch/i.html?_from=R40&_nkw=badminton+net+sportcraft&rt=nc&modules=SEARCH_REFINEMENTS_MODEL_V2%3Afa&_aspectname=delivery&_fsrp=1&pageci=612010d9-052d-11ea-a207-74dbd1809a38"},"w4-w20":{"isExpanded":true},"w4-w28":{"params":{"_fsrp":"1","_aspectname":"globals","_nkw":"badminton net sportcraft","_from":"R40","rt":"nc","pageci":"612010d9-052d-11ea-a207-74dbd1809a38","modules":"SEARCH_REFINEMENTS_MODEL_V2:fa"},"URL":"https://www.ebay.com/sch/i.html?_from=R40&_nkw=badminton+net+sportcraft&rt=nc&modules=SEARCH_REFINEMENTS_MODEL_V2%3Afa&_aspectname=globals&_fsrp=1&pageci=612010d9-052d-11ea-a207-74dbd1809a38"},"w4-w29":{"params":{"_fsrp":"1","_nkw":"badminton net sportcraft","_from":"R40","rt":"nc","modules":"SEARCH_REFINEMENTS_MODEL_V2:fa","pageci":"612010d9-052d-11ea-a207-74dbd1809a38"},"URL":"https://www.ebay.com/sch/i.html?_from=R40&_nkw=badminton+net+sportcraft&rt=nc&modules=SEARCH_REFINEMENTS_MODEL_V2%3Afa&_fsrp=1&pageci=612010d9-052d-11ea-a207-74dbd1809a38"},"w4":{"isSafariBrowser":false,"useAjaxUrl":true,"isBrowse":false,"baseUrl":"https://www.ebay.com/sch/i.html?_from=R40&_nkw=badminton+net+sportcraft&rt=nc","isRedesign":true},"w6":{"useHover":true,"shouldFocus":true},"w7":{"useHover":true,"shouldFocus":true},"w8":{"useHover":true,"shouldFocus":true},"w9":{"useHover":true,"shouldFocus":true},"w10-w0-w0":{"svcEndPoint":"https://www.ebay.com/sch/FindingCustomization?_from=R40&_nkw=badminton+net+sportcraft&pid=2333164&requestType=experienceService","svcErrorMsg":"There seems to be a problem serving the request at this time"},"w10-w0":{"useHover":true,"shouldFocus":false},"w10":{"useHover":true,"shouldFocus":false},"w11":{"isFollowing":false,"shouldEmit":false},"srp-river-results-w0":{"swPrefetchEnabled":false,"swPrefetchMaxCacheAge":180,"swViPrefetchCacheKey":"SRPVIPREFETCH","swViPrefetchCacheRefresh":false,"swPrefetchMacCacheEntries":100000,"swAllowedResources":""},"srp-river-results":{"isQuantumMetricEnabled":false},"w13":{"prefetchCount":5,"prefetchUrl":"//www.ebay.com/lit/v1/picture?fieldGroups=PICTURESONLY&items=333236247616,362653010777&callback ...
# t.w0=$.w0
# t.w1=$.w1
# t.w2=$.w2
# t.w3=$.w3
# t["w4-w0"]=$["w4-w0"]
# t["w4-w3"]=$["w4-w3"]
# t["w4-w5"]=$["w4-w5"]
# t["w4-w10"]=$["w4-w10"]
# t["w4-w11"]=$["w4-w11"]
# t["w4-w16"]=$["w4-w16"]
# t["w4-w17"]=$["w4-w17"]
# t["w4-w19"]=$["w4-w19"]
# t["w4-w20"]=$["w4-w20"]
# t["w4-w28"]=$["w4-w28"]
# t["w4-w29"]=$["w4-w29"]
# t.w4=$.w4
# t.w6=$.w6
# t.w7=$.w7
# t.w8=$.w8
# t.w9=$.w9
# t["w10-w0-w0"]=$["w10-w0-w0"]
# t["w10-w0"]=$["w10-w0"]
# t.w10=$.w10
# t.w11=$.w11
# t["srp-river-results-w0"]=$["srp-river-results-w0"]
# t["srp-river-results"]=$["srp-river-results"]
# t.w13=$.w13
# t.w14=$.w14
# t["s-modal"]=$["s-modal"]
# }());
# $markoWidgets("w0,w1,w2,w3,w4-w0,w4-w3,w4-w4-0,w4-w4,w4-w5,w4-w10,w4-w11,w4-w16,w4-w17,w4-w19,w4-w20,w4-w28,w4-w29,w4,scandal100588,scandal100586,scandal100587,w5,w6,w7,w8,w9,w10-w0-w0,w10-w0,w10,w11-follow,w11,w12,srp-river-results-listing1-w1,srp-river-results-listing1,srp-river-results-listing2,srp-river-results-SEARCH_PAGINATION_MODEL_V2-w0,srp-river-results-SEARCH_PAGINATION_MODEL_V2,srp-river-results-w0,srp-river-results,w13,w14,w15,scandal100659,scandal100589,w16,w17,scandal100584,w18,w19,w20,w21,w22,s-modal")</script><script>var c;if(window.MutationObserver){var e=function(){var b=!1;return function(){if(!b){var a=new XMLHttpRequest;a.open("POST","./update",!0);a.setRequestHeader("srt","01000400000050d13ca51bb560b25ce801d28716550167b835be8fdf8248e633c97fd6d60328c148c8751dcc610b45e4166971e67844071c0a7e909908e03f9da1d6e316dcabefd5769de28c392894ccfcad78a4993833");a.send(JSON.stringify({t:"plb",v:"1"}));b=!0;c&&c.disconnect()}}}(),f=function(b){var a=document.querySelector(".srp-river-main li.s-item");b.forEach(function(){null!==a&&"none"!==getComputedStyle(a).display||e()})};(new MutationObserver(function(b){b.forEach(function(a){"attributes"===a.type&&"style"===a.attributeName&&document.querySelectorAll("iframe").forEach(function(d){if(-1<d.src.indexOf("pbjikboenpfhbbejgkoklgkhjpfogcam")||
# -1<d.src.indexOf("amazon"))d.parentNode.removeChild(d),document.getElementsByTagName("html")[0].style.marginTop=0,$(document).trigger("rover",{ex1:46118})})})})).observe(document.getElementsByTagName("html")[0],{attributes:!0});var g=document.querySelector(".srp-river-main li.s-item");null===g||"none"===getComputedStyle(g).display?e():(c=new MutationObserver(f),c.observe(g,{attributes:!0,childList:!0,subtree:!0}))};</script></img></body></html><!-- RcmdId srpnweb,RlogId t6pwvit%60d%3D9iptpwvit%60d*0266632-16e5ee82e75-0x2203 --><!-- SiteId: 0, Environment: production, AppName: srpnweb, PageId: 2334524 -->

# %%
product_li = soup.find_all('li', class_="s-item")

# %%
print(product_li)
# Out:
# [<li class="s-item"><div style="display:inline;"><div class="s-item__title--tagblock"><span role="text"><span class="s-jm3aicp">7</span><span class="s-qd9gx2">S</span><span class="s-jm3aicp">0</span><span class="s-qd9gx2">P</span><span class="s-qd9gx2">O</span><span class="s-qd9gx2">N</span><span class="s-qd9gx2">S</span><span class="s-qd9gx2">O</span><span class="s-jm3aicp">A</span><span class="s-qd9gx2">R</span><span class="s-jm3aicp">P</span><span class="s-jm3aicp">A</span><span class="s-jm3aicp">7</span><span class="s-jm3aicp">E</span><span class="s-qd9gx2">E</span><span class="s-qd9gx2">D</span><span class="s-qd9gx2"></span><span class="s-qd9gx2"></span><span class="s-jm3aicp">U</span><span class="s-jm3aicp">J</span><span class="s-qd9gx2"></span><span class="s-jm3aicp">0</span><span class="s-jm3aicp">F</span><span class="s-jm3aicp">J</span><span class="s-qd9gx2"></span><span class="s-qd9gx2"></span><span class="s-jm3aicp"></span><span class="s-jm3aicp"></span></span></div></div></li>, <li class="s-item" data-view="mi:1686|iid:1" data-widget="/srpnweb$1.0.0/src/common-utils/component-parts/widget-no-update" id="srp-river-results-listing1"><div class="s-item__wrapper clearfix"><div class="s-item__image-section"><div class="s-item__image"><a _sp="p2351460.m1686.l7400" aria-hidden="true" data-track='{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"moduledtl":"mi:1686|iid:1|li:7400|luid:1|scen:Listings","parentrq":"5ee82e7916e0aad2e0f9ecd6fffa9fc0","pageci":"612010d9-052d-11ea-a207-74dbd1809a38"}}' href="https://www.ebay.com/itm/VINTAGE-SPORTCRAFT-BADMINTON-RACQUETS-MISSING-NET/333236247616?hash=item4d966d9c40:g:W68AAOSw7cldBun-" tabindex="-1"><div class="s-item__image-wrapper"><div class="s-item__image-helper"></div><img alt="VINTAGE SPORTCRAFT BADMINTON RACQUETS MISSING NET " class="s-item__image-img" loading="eager" onload='SITE_SPEED.ATF_TIMER.measure(this); if (performance &amp;&amp; performance.mark) { performance.mark("first-meaningful-paint"); }' src="https://i.ebayimg.com/thumbs/images/g/W68AAOSw7cldBun-/s-l225.jpg"/></div></a></div></div><div class="s-item__info clearfix"><div class="s-item__title-hotness"></div><a _sp="p2351460.m1686.l7400" class="s-item__link" data-track='{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"moduledtl":"mi:1686|iid:1|li:7400|luid:1|scen:Listings","parentrq":"5ee82e7916e0aad2e0f9ecd6fffa9fc0","pageci":"612010d9-052d-11ea-a207-74dbd1809a38"}}' href="https://www.ebay.com/itm/VINTAGE-SPORTCRAFT-BADMINTON-RACQUETS-MISSING-NET/333236247616?hash=item4d966d9c40:g:W68AAOSw7cldBun-"><div style="display:flex;"><div class="s-item__title--tagblock"><span role="text"><span class="s-qd9gx2"></span><span class="s-jm3aicp">N</span><span class="s-jm3aicp">S</span><span class="s-qd9gx2"></span><span class="s-qd9gx2"></span><span class="s-jm3aicp">1</span><span class="s-qd9gx2"></span><span class="s-qd9gx2"></span><span class="s-jm3aicp">S</span><span class="s-qd9gx2"></span><span class="s-qd9gx2"></span><span class="s-jm3aicp">S</span><span class="s-jm3aicp">7</span><span class="s-qd9gx2"></span><span class="s-jm3aicp">I</span><span class="s-qd9gx2"></span><span class="s-qd9gx2"></span><span class="s-jm3aicp">H</span><span class="s-jm3aicp">I</span><span class="s-jm3aicp">9</span><span class="s-qd9gx2"></span><span class="s-qd9gx2"></span><span class="s-qd9gx2"></span><span class="s-qd9gx2"></span><span class="s-jm3aicp"></span><span class="s-jm3aicp"></span><span class="s-jm3aicp"></span><span class="s-qd9gx2"></span></span></div></div><h3 class="s-item__title">VINTAGE SPORTCRAFT BADMINTON RACQUETS MISSING NET </h3></a><div class="s-item__subtitle"><span class="SECONDARY_INFO">Pre-Owned</span></div><div class="s-item__details clearfix"><div class="s-item__detail s-item__detail--primary"><span c ...

# %%
for single_product_li in product_li:
    
    image_div =single_product_li.find('a')
    anchor_tag=image_div

# %%
url1
# Out:
# 'https://www.ebay.com/itm/NEW-Sportcraft-32ft-Volleyball-Net-Tie-On-Badminton-Beach-Outdoor-Indoor-Tennis/362653010777?hash=item546fcdcb59:m:mVGUvN1c4SVzz10nJ4L4wyQ'

# %%
url1=( anchor_tag['href'])

# %%
rough_url=url1.split('/')[-1]

# %%
rough_url.split('?')[0]
# Out:
# '362653010777'

# %%
  pagination_div = soup.find('a', attrs={'title': 'Next'})
  if pagination_div is not None:
    pagination_url = base_url + pagination_div.get('href')
    print('Next Url :' + pagination_url)
    search_category('pagination', category_name, pagination_url)

# %%
def get_single_product(url, category_name):
    product_details = {}
    ua = UserAgent()
    header = {'User-Agent': str(ua)}
    rough_url= url.split('/')[-1]
    product_details['product_id']
    ajax_url = 'https://www.ebay.com/itm/' + product_details['product_id']
    page_response = requests.get(ajax_url, headers=header).json()

    product_details['model_number'] = page_response['primaryItemData']['info']['modelNumber']
    product_details['product_title'] = page_response['primaryItemData']['info']['productLabel']
    product_details['product_description'] = page_response['primaryItemData']['info']['description']
    product_price = page_response['primaryItemData']['itemExtension']['pricing']
    product_details['average_rating'] = page_response['primaryItemData']['ratingsReviews']['averageRating']
    product_details['price'] = str(product_price['specialPrice']) + ' / ' + str(product_price['originalPrice'])

    product_image_list = []
    if 'media' in page_response['primaryItemData']:
        for images in page_response['primaryItemData']['media']['mediaList']:
            if 'video' in images:
                print("Video")
            elif 'height' in images and images['height'] == '1000':
                product_image_list.append(images['location'])
        product_details['product_images'] = ','.join(product_image_list)
    else:
        product_details['product_images'] = 'Not found'

    product_specification_list = []
    product_highlights_list = []
    product_manual_list = []
    product_descriptive_list = []
    if 'attributeGroups' in page_response['primaryItemData']:
        for specification in page_response['primaryItemData']['attributeGroups']:
            if specification['groupType'] == 'functional details' or specification['groupType'] == 'supplemental dimensions' or specification['groupType'] == 'base dimensions':
                for specifications in specification['entries']:
                    product_specification_list.append(specifications['name'] + " : " + specifications['value'])
            elif specification['groupType'] == 'descriptive':
                for descriptive in specification['entries']:
                    product_descriptive_list.append(descriptive['name'] + " : " + descriptive['value'])
            elif specification['groupType'] == 'product highlights':
                for highlights in specification['entries']:
                    product_highlights_list.append(highlights['name'] + " : " + highlights['value'])
            elif specification['groupType'] == 'pdf documents':
                for manuals in specification['entries']:
                    product_manual_list.append(manuals['name'] + " : " + manuals['url'])

        product_details['product_sepcifications'] = ','.join(product_specification_list)
        product_details['product_highlights'] = ','.join(product_highlights_list)
        product_details['product_manuals'] = ','.join(product_manual_list)
        product_details['product_descriptive'] = ','.join(product_descriptive_list)
    else:
        product_details['product_sepcifications'] = 'Not found'
        product_details['product_highlights'] = 'Not found'
        product_details['product_manuals'] = 'Not found'
        product_details['product_descriptive'] = 'Not found'

    print(product_details)

    csv_creator.product_csv_creator_file(product_details, category_name)

#get_data_from_new_url('https://www.homedepot.com/p/Whirlpool-25-cu-ft-French-Door-Refrigerator-in-Fingerprint-Resistant-Stainless-Steel-WRX735SDHZ/301859152')
#get_single_product('https://www.homedepot.com/p/Whirlpool-25-cu-ft-French-Door-Refrigerator-in-Fingerprint-Resistant-Stainless-Steel-WRX735SDHZ/301859152')
search_category('category_name', 'Hand Tools - Clamp and Vise', '')

# %%
 page_response=requests.get("https://www.ebay.com/itm/333236247616", headers=header)

# %%
page_response.status_code
if 'json' in page_response.headers.get('Content-type'):
    js=page_response.json()
else:
    print('Response content is not in JSON format.')
    js='spam'
# Out:
# Response content is not in JSON format.

# %%
# Out:
# 'spam'
